# %% [markdown]
# # Предсказание стоимости акций

# %% [markdown]
# # 1. Подготовка<a class='anchor' id='1'>

# %% [markdown]
# ## 1) Импортируем библиотеки<a class='anchor' id='1_1'>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import math

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
import lightgbm as lgb

from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import plot_model
from keras.models import load_model

from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# #### - объявим класс DataExplorer и наполним его методами для анализа

# %%
class DataExplorer:
    
    def __init__(self):
        self.report = []
        self.final_report = []
      
    def histogram(self, data, n_bins, range_start, range_end, grid, cumulative=False, x_label = '', y_label = '', title = ''):
        
        """
        Простая гистограмма
        
        Пример:
        histogram(df, 100, 0, 150, True, 'Количество иксов', 'Количество игриков', 'Заголовок')
        
        data - датасет
        n_bins - количество корзин
        range_start - минимальный икс для корзины
        range_end - максимальный икс для корзины
        grid - рисовать сетку или нет (False / True)
        
        
        histogram(data, n_bins, range_start, range_end, grid, x_label = "", y_label = "", title = "")
        """
        
        # Создаем объект - график
        _, ax = plt.subplots()

        # Задаем параметры
        ax.hist(data, bins = n_bins, range = (range_start, range_end), cumulative = cumulative, color = '#4169E1')

        # Добавляем сетку
        if grid == True:
            ax.grid(color='grey', linestyle='-', linewidth=0.5)
        else:
            pass

        # Добавляем медиану, среднее и квартили
        ax.axvline(data.median(),linestyle = '--', color = '#FF1493', label = 'median')
        ax.axvline(data.mean(),linestyle = '--', color = 'orange', label = 'mean')
        ax.axvline(data.quantile(0.1),linestyle = '--', color = 'yellow', label = '1%')
        ax.axvline(data.quantile(0.99),linestyle = '--', color = 'yellow', label = '99%')
        ax.legend()
        ax.set_ylabel(y_label)
        ax.set_xlabel(x_label)
        ax.set_title(title)                             
             
   
    def firstsight(self, data):
        
        """
        Возврашает пять первых, последних и случайных элементов датасета для дальнейшего вывода с помощью Display
        
        Пример:
        head, tail, sample = explorer.firstsight(df)
        """
        
        head = data.head(5)
        tail = data.tail(5)
        sample = data.sample(5)
        
        return head, tail, sample
        
        
    def smape(self, y_test, y_predict): 
        
        """
        Расcчитывает метрику SMAPE
        
        Пример:
        smape(y_test, y_predict)
        """
                
        y_test, y_predict = np.array(y_test), np.array(y_predict)
        return np.mean(np.abs(y_predict - y_test) / ((np.abs(y_test) + np.abs(y_predict) + 0.1**99)/2)) * 100
    
    
    def mape(self, y_test, y_predict):
        
        """
        Расcчитывает метрику MAPE
        
        Пример:
        mape(y_test, y_predict)
        """
                
        y_test, y_predict = np.array(y_test), np.array(y_predict)
        return np.median((np.abs((y_test - y_predict)) / (y_test + 0.1**100)) * 100)
       
        
    def grid_search(self, model, param_grid, cv, scoring, x, y):
        
        """
        Поиск по сетке с заданными параметрами
        
        Пример:
        lr_geo_one = explorer.grid_search(lr, param_grid, 5, 'neg_mean_squared_error', x_train, y_train)
        """
        
        grid_model = GridSearchCV(model, param_grid=param_grid, cv=cv, scoring=scoring, iid=False, verbose=1, n_jobs=-1)
        grid_model.fit(x, y)
        best_estimator = grid_model.best_estimator_
        return best_estimator
    
    def predictions_plotting(self):
        for index in range(len(self.final_report)):
            sns.set(style='whitegrid')
            dims = (25, 10)
            fig, ax = plt.subplots(figsize=dims)
            plt.plot(y_test, color='red', label='Реальная стоимость акций')
            plt.plot(self.final_report.iloc[index].predictions, color='blue', label=f'Стоимость акций, предсказанная {self.final_report.iloc[index].model}')
            plt.title(f'Прогноз стоимости акций Газпрома по версии модели {self.final_report.iloc[index].model}')
            plt.xlabel('Дни')
            plt.ylabel('Цена')
            plt.legend()
            plt.show()
    
    def reporter(self, models):
                        
        """
        Функция принимает на вход список моделей, обучает их и собирает метрики
        """
        
        for model in models:
            print('\n', model[0], '\n')
            grid_search = explorer.grid_search(model[1], model[2], 5, 'neg_mean_squared_error', x_train, y_train)
            print(grid_search)

            self.predicted = np.ravel(grid_search.predict(x_test))
            rmse = mean_squared_error(y_test, self.predicted)**0.5
            smape = explorer.smape(y_test, self.predicted)
            mape = explorer.mape(y_test, self.predicted)

            self.report.append((model[0], rmse, smape, mape, grid_search, self.predicted))

        self.final_report = pd.DataFrame(self.report, columns=['model', 'rmse', 'smape', 'mape', 'grid_params', 'predictions'])
            
    class Display(object):
        """
        Выводит HTML представление нескольких объектов
        
        Пример:
        Display(head, tail, sample)
        
        """
        template = """<div style="float: left; padding: 10px;">
        <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
        </div>"""
        def __init__(self, *args):
            self.args = args

        def _repr_html_(self):
            return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                             for a in self.args)

        def __repr__(self):
            return '\n\n'.join(a + '\n' + repr(eval(a))
                               for a in self.args)

# %%
explorer = DataExplorer()

# %% [markdown]
# #### - зафиксируем случайные числа

# %%
np.random.seed(42)

# %% [markdown]
# ## 2) Прочитаем данные в переменную<a class='anchor' id='1_2'>

# %%
df = pd.read_csv('df_full.csv', delimiter=';', index_col=[0], parse_dates=[0])

# %% [markdown]
# ## 3) Выведем первые, последние и случайные пять строк каждого из датасетов, общую информацию<a class='anchor' id='1_3'>

# %%
head, tail, sample = explorer.firstsight(df)
explorer.Display('head', 'tail', 'sample')
# Out:
# head
#              price
# date
# 2008-10-16  110.00
# 2008-10-17  112.20
# 2008-10-20  107.00
# 2008-10-21  114.00
# 2008-10-22  113.11
#
# tail
#              price
# date
# 2021-02-11  223.45
# 2021-02-12  220.78
# 2021-02-15  228.49
# 2021-02-16  229.95
# 2021-02-17  232.32
#
# sample
#              price
# date
# 2018-07-18  138.86
# 2017-08-29  118.50
# 2017-10-06  123.54
# 2020-06-26  192.80
# 2019-04-25  160.19

# %% [markdown]
# &#9889; **Вывод:**
#
# 1. Визальное ознакомление проблем с датасетом не выявило.
# 2. Столбец 'date' использован как индекс: даты идут последовательно, интервал в один день.
# 3. Если исходить из того, что индекс не требует сортировки - в датасете представлена выборка за период от октября 2008 года до февраля 2021 года (последняя дата - 17 февраля 2021 года).

# %% [markdown]
# ## 4) Выведем общую информацию о датасете, общую статистику<a class='anchor' id='1_4'>

# %% [markdown]
# #### - общая информация о датасете

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3094 entries, 2008-10-16 to 2021-02-17
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   3094 non-null   float64
# dtypes: float64(1)
# memory usage: 48.3 KB

# %% [markdown]
# #### - общая статистика с 1% и 99% перцентилями

# %%
df.describe(percentiles = [.01, .25, .5, .75, .99]).T
# Out:
#         count       mean        std   min        1%      25%     50%      75%  \
# price  3094.0  159.58552  31.871572  88.0  108.8151  138.015  150.92  175.085
#
#             99%    max
# price  252.8128  269.9

# %% [markdown]
# С учетом того, что 99 % всех значений не превышает 252.81 рубля, а максимальное значение 269.9 рублей - вероятно в датасете нет сильных выбросов.

# %% [markdown]
# #### - построим ящик с усами, чтобы проверить выбросы

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Есть выбросы, влияющие на среднее. Проверим количество выбросов:

# %%
len(df.query('price > 230'))
# Out:
# 155

# %% [markdown]
# Всего 155 из 3094 наблюдений (примерно 5 процентов). Избавимся от выбросов, поскольку они 1) влияют на среднее и 2) в стоимости акций лучше их не учитывать.

# %% [markdown]
# #### - избавимся от 80 выбросов в датасете

# %%
df = df.query('price < 231')

# %%
df.shape
# Out:
# (2948, 1)

# %% [markdown]
# &#9889; **Вывод:**
#
# 1. В датасете 3094 строк, без пропусков.
# 2. Минимальная стоимость акций - 88 рублей, максимальная - 269.90 рублей, при этом 99 % всех значений не превышает 252.81 рубль. Среднее стоимость - 159.58 рублей.
# 3. График "ящик с усами" выявил выбросы: всего 155 из 3094 наблюдений (0,05%).
# 4. Принято решение избавиться от 155 из 3094 наблюдений (0,05%): данные наблюдения могут быть важными, являтся частью явления, но они не объясняются датасетом и сильно влияют на среднее.

# %% [markdown]
# # 2. Анализ<a class='anchor' id='2'>

# %% [markdown]
# ## 1) Построим график временного ряда<a class='anchor' id='2_1'>

# %%
df.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# При таком масштабе усматривается тренды. Нужно уменьшить масштаб.

# %% [markdown]
# #### - ресемплиуем данные по трем месяцам и визуализируем результат

# %%
df.resample('12W').sum().plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# График имеет ожидаемый яркий выброс в 2020 году, но не имеет ярко выраженный тренд. Как следствие, ряд стационарный.

# %% [markdown]
# #### - построим гистограмму

# %%
explorer.histogram(df.price, 50, 80, 250, True)

# %% [markdown]
# Унимодальное распредление, скошено вправо, есть длинный хвост, медиана и среднее разведены.

# %% [markdown]
# ## 2) Скользящее среднее и скользящее среднее отклонение<a class='anchor' id='2_2'>

# %% [markdown]
# #### - вычислим и визуализируем скользящее среднее, скользящее среднее отклонение на копии датасета

# %%
df_roll_mean = df.copy()
df_roll_mean = df_roll_mean.resample('3D').sum()
df_roll_mean['rolling_mean'] = df.rolling(30).mean()
df_roll_mean.dropna(inplace=True)
df_roll_mean['std'] = df_roll_mean.price.rolling(30).std()
df_roll_mean.plot(figsize=(15, 10))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Вывод:<a class='anchor' id='2_conclusion'>

# %% [markdown]
# Среднее и стандартное отклонение сравнительно стабильны, и даже при значительном сглаживании не заметен тренд - ряд стационарен.

# %% [markdown]
# # 3. Обучение<a class='anchor' id='3'>

# %% [markdown]
# ## 1) Создадим признаки для целей обучения моделей<a class='anchor' id='3_1'>

# %% [markdown]
# #### - подготовим функцию для создания признаков

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['price'].shift(lag)

    data['rolling_mean'] = data['price'].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# #### - применим функцию с отстающими значениями равным 30 и скользящим средним равным 30, чтобы задать общий тренд временного ряда

# %%
make_features(df, 30, 30)

# %% [markdown]
# #### - проверим, что число пропусков в строках, полученных в результате сдвига, не превышает 7 строк

# %%
df.isna().sum().max()
# Out:
# 30

# %% [markdown]
# Придется удалить всего 30 строк из 2948 (0,01%).

# %% [markdown]
# #### - избавимся от строк с пропусками - 30 строк из 2948 (0,01%).

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2918, 35)

# %%
df.head()
# Out:
#              price  month  day  dayofweek   lag_1   lag_2   lag_3   lag_4  \
# date
# 2008-12-02  104.99     12    2          1  117.25  119.21  115.50  109.73
# 2008-12-03  114.00     12    3          2  104.99  117.25  119.21  115.50
# 2008-12-04  110.00     12    4          3  114.00  104.99  117.25  119.21
# 2008-12-05  105.00     12    5          4  110.00  114.00  104.99  117.25
# 2008-12-08  112.22     12    8          0  105.00  110.00  114.00  104.99
#
#              lag_5   lag_6  ...  lag_22  lag_23  lag_24  lag_25  lag_26  \
# date                        ...
# 2008-12-02  116.01   95.01  ...   98.00   88.00   99.98  105.00  113.11
# 2008-12-03  109.73  116.01  ...  115.00   98.00   88.00   99.98  105.00
# 2008-12-04  115.50  109.73  ...  126.40  115.00   98.00   88.00   99.98
# 2008-12-05  119.21  115.50  ...  137.13  126.40  115.00   98.00   88.00
# 2008-12-08  117.25  119.21  ...  155.10  137.13  126.40  115.00   98.00
#
# ...

# %% [markdown]
# &#9889; **Вывод:**
#
# 1. Были созданы признаки из остающими значениями равным 30 и скользящим средним равным 30.
# 2. В результате получен датасет с 30 строками с пропусками из 2948 (0,015%), а также 34 столбцами признаками, из которых 30 - отстающие значения, 3 - месяц, день и день недели, 1 - скользящее среднее.
# 3. После создания признаков и удаления 30 строк с пропусками был получен датасет в 2918 строки и 35 столбцов.

# %% [markdown]
# ## 2) Cоздадим словарь для поиска наилучших параметров модели, инициализируем модели, выберем параметры для подбора<a class='anchor' id='3_2'>

# %% [markdown]
# #### - словарь с моделями

# %%
models = []

# %% [markdown]
# #### - LinearRegression

# %%
lr = LinearRegression(n_jobs=-1)

param_grid={'fit_intercept':[True, False], 'normalize':[True, False], 'copy_X':[True, False]}

models.append(('Linear Regression', lr, param_grid))

# %% [markdown]
# #### - RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state=42, n_estimators=30, max_features='auto', n_jobs=-1)

param_grid = {'max_depth': np.arange(10, 20, 2), 'min_samples_split': np.arange(2, 10, 2)}

models.append(('RandomForestRegressor', rfr, param_grid))

# %% [markdown]
# #### - LGBMRegressor

# %%
lg = lgb.LGBMRegressor(num_leaves=600, n_estimators=300, random_state=42)

param_grid = {'n_estimators' : [150, 600],
              'num_iterations' : [300, 600],
              'learning_rate' : [0.001, 0.01]}

models.append(('LGBMRegressor', lg, param_grid))

# %% [markdown]
# #### - CatboostRegressor

# %%
cbregressor = CatBoostRegressor(n_estimators=300, random_state=42, logging_level='Silent')

param_grid = {'learning_rate' : [0.001, 0.01],
              'n_estimators' : [150, 600] 
             }

models.append(('CatBoostRegressor', cbregressor, param_grid))

# %% [markdown]
# ## 3) Разделим выборку на обучающую и тестовую в соотношении 90:10, выделим целевой признак<a class='anchor' id='3_3'>

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('price', axis = 1), df.price, train_size=0.9, shuffle=False)

# %% [markdown]
# #### - целевые признаки превратим в одномерный массив

# %%
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# %% [markdown]
# # 4. Тестирование<a class='anchor' id='4'>

# %% [markdown]
# ## 1) Подберем наилучшие параметры для моделей, сохраним параметры и соберем метрики<a class='anchor' id='4_2'>

# %%
explorer.reporter(models)
# Out:
#  Linear Regression
#
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    3.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# LinearRegression(n_jobs=-1, normalize=True)
#
#  RandomForestRegressor
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   18.7s finished
# RandomForestRegressor(max_depth=18, min_samples_split=4, n_estimators=30,
#                       n_jobs=-1, random_state=42)
#
#  LGBMRegressor
#
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:   27.0s finished
# ...

# %% [markdown]
# ## 3) Выведем отчет с сортировкой по значению RMSE (без параметров моделей)<a class='anchor' id='4_3'>

# %%
explorer.final_report[['model', 'rmse', 'smape', 'mape']].sort_values(by='rmse').style.highlight_min(color='lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
# #T_89802_row0_col1,#T_89802_row0_col2,#T_89802_row0_col3{
#             background-color:  lightgreen;
#         }</style><table id="T_89802_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >rmse</th>        <th class="col_heading level0 col2" >smape</th>        <th class="col_heading level0 col3" >mape</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89802_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_89802_row0_col0" class="data row0 col0" >Linear Regression</td>
#                         <td id="T_89802_row0_col1" class="data row0 col1" >3.908129</td>
#                         <td id="T_89802_row0_col2" class="data row0 col2" >1.444100</td>
#                         <td id="T_89802_row0_col3" class="data row0 col3" >1.109559</td>
#             </tr>
# ...

# %% [markdown]
# ## 4) Визуализируем предсказание моделей<a class='anchor' id='4_4'>

# %%
explorer.predictions_plotting()

# %% [markdown]
# ## Вывод:<a class='anchor' id='4_conclusion'>

# %% [markdown]
# 1. Лучше всего с задачей справилась **линейная регрессия**:
#
#     - RMSE - 3.908129,
#     - SMAPE - 3.908129,
#     - MAPE - 1.109559.
#
#
# 2. Результаты других моделей в порядке возрастания:
#
#     - RandomForestRegressor - RMSE 4.659215.
#     - LGBMRegressor - RMSE 4.704846,
#     - CatBoostRegressor - RMSE 5.762661
#
#
# 3. Итоговые результаты представлены в таблице, параметры моделей сохранены.
